# %% [markdown]
# # Recurent SNN Batch Size Test
#
# This notebook takes pre-trained weights from a recurrent ANN and uses them to perform inference using a network of spiking neurons.
#
# Spiking network must be the same shape as the pre-trained ANN. Must also use same dataset used to train ANN.
#
# ANN must use ReLU as the nonlinear activation between layers.
#
# Performs weight balancing on all layers.
#
# Effects to be studied:
# - batch size effect on accuracy
# - batch-size-delay mismatch rectefication method effect on accuracy
#     - extrapolate
#     - reuse

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
from torch import nn
from tqdm import tqdm
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
from SpikingNetwork import SNN, poisson_train

# %% [markdown]
# ## Load ANN Model

# %%
# specify file name and directory of ANN then load

model_dir = "Recurrent ANN Models/"
model_name = "RANN_12.pth"

# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        """ Builds feed-forward layers """
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(64, 48, bias=False),
            nn.ReLU(),
        )
        self.rnn = nn.RNN(48, 16, nonlinearity='relu', bias=False)
        self.out = nn.Sequential(
            nn.Linear(16, 6, bias=False),
            nn.LogSoftmax(dim=1),
        )

    def forward(self, q):
        """ Implements feed-forward then recurrent layers """
        ff_q = []
        for word in q:
            ff_q.append(self.ff(word))
        ff_q = torch.stack(ff_q)
        h_N = Variable(torch.zeros(1, 16)).to(device)
        for word in ff_q:
            if not torch.all(word.eq(0)):
                rnn_out, h_N = self.rnn(word, h_N)
            else:
                break
        output = self.out(rnn_out)
        return output

# load pre-trained ANN 
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load(model_dir + model_name))
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (ff): Sequential(
#     (0): Linear(in_features=64, out_features=48, bias=False)
#     (1): ReLU()
#   )
#   (rnn): RNN(48, 16, bias=False)
#   (out): Sequential(
#     (0): Linear(in_features=16, out_features=6, bias=False)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# ## Load Data

# %%
# Load and prepare data

# load data
f = open("Training Data\\train_5500.txt")
data = f.read()

# split data into sentences
sents = data.split('\n')

# split each sentence into words
for i in range(len(sents)):
    sents[i] = sents[i].split(' ')[:-1]
    
# load in word to vector converter
w2v_load = Word2Vec.load("Usable Word2Vec Model\\word2vec.model")
wv = w2v_load.wv

# perform conversion
vec_data = []
for sent in sents[:-1]:
    vecs = []
    vecs.append(sent[0])
    for word in sent[1:]:
        try:
            vecs.append(torch.from_numpy(wv[word]))
        except:
            pass
    vecs.append(torch.zeros(64))
    vec_data.append(vecs)

# pad all sentences to length of longest sentence
max_len = max([len(sent) for sent in vec_data])
vec_data_pad = []
for sent in vec_data:
    pad_len = max_len - len(sent)
    for i in range(pad_len):
        sent.append(torch.zeros(64))
    vec_data_pad.append(sent)
vec_data = vec_data_pad
    
# split into training and test data
train_data = vec_data[:5000]
test_data = vec_data[5000:-1]
# Out:
# C:\Users\Liamr\AppData\Local\Temp\ipykernel_8520\3114109652.py:25: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:212.)
#   vecs.append(torch.from_numpy(wv[word]))

# %%
# create custom DataSet then make Dataloader

ans_key = { 'DESC' :  0,
            'ENTY' :  1,
            'ABBR' :  2,
            'HUM'  :  3,
            'LOC'  :  4,
            'NUM'  :  5
            }

class QuestionDataset(Dataset):
    """ Question Dataset """
    
    def __init__(self, data):
        """
        data = list of (list of words -- first word is label)
        """
        self.labels = []
        self.sents = []
        for sent in data:
            lab_val = ans_key[sent[0].split(":")[0]]
            lab_arr = torch.tensor(lab_val)
            self.labels.append(lab_arr)
            self.sents.append(sent[1:])
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        sent = self.sents[idx]
        label = self.labels[idx]
        return sent, label

test_DSet = QuestionDataset(test_data)

# Create data loader
batch_size = 1
test_dataloader = DataLoader(test_DSet, batch_size=batch_size, shuffle=True)

# %%
# run some test epochs

# create loss function
loss_fn = nn.NLLLoss()

# define test routine
def test_ANN(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    i = 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = torch.stack(X).to(device), y.to(device) #torch.FloatTensor(y).to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            print("Actual: {0} -- Inferred: {1}".format(y.item(), pred.argmax(1).item()))
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

epochs = 1
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    test_ANN(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 0 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 4 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 0 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 0
# Actual: 1 -- Inferred: 3
# Actual: 4 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 2 -- Inferred: 2
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 3
# Actual: 1 -- Inferred: 0
# Actual: 0 -- Inferred: 2
# Actual: 1 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 2 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 3
# Actual: 5 -- Inferred: 4
# Actual: 0 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 2
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 0
# Actual: 4 -- Inferred: 1
# Actual: 5 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 0
# Actual: 4 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 4
# Actual: 3 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 0
# Actual: 1 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 1
# Actual: 4 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 2 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 4
# Actual: 5 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 3
# Actual: 0 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 2 -- Inferred: 2
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 2 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 0
# Actual: 5 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 4 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 2 -- Inferred: 2
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 4 -- Inferred: 3
# Actual: 3 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 3
# Actual: 0 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 1
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 4 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 2 -- Inferred: 0
# Actual: 4 -- Inferred: 4
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 3
# Actual: 0 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 1
# Actual: 2 -- Inferred: 2
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 2 -- Inferred: 2
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 1 -- Inferred: 0
# Actual: 3 -- Inferred: 2
# Actual: 1 -- Inferred: 0
# Actual: 0 -- Inferred: 0
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 5 -- Inferred: 5
# Actual: 0 -- Inferred: 0
# Actual: 5 -- Inferred: 5
# Actual: 1 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 5 -- Inferred: 5
# Actual: 4 -- Inferred: 3
# Actual: 4 -- Inferred: 1
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 5 -- Inferred: 5
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 0 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 1 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Actual: 4 -- Inferred: 4
# Actual: 4 -- Inferred: 4
# Actual: 0 -- Inferred: 0
# Actual: 3 -- Inferred: 3
# Actual: 3 -- Inferred: 3
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.828692
#
# Done!

# %% [markdown]
# ## Transfer Weights to SNN

# %%
# get weights from ANN

param_list = [*model.parameters()]
i = 0
for lay in param_list:
    i += 1
    print("Layer {0}".format(i))
    print(lay.shape)
    print(lay)

w_1 = param_list[0].cpu().detach().numpy()
w_2 = param_list[1].cpu().detach().numpy() # rec layer from prev layer (input)
w_3 = param_list[2].cpu().detach().numpy() # rec layer from hidden layer
w_4 = param_list[3].cpu().detach().numpy()
# Out:
# Layer 1
# torch.Size([48, 64])
# Parameter containing:
# tensor([[-0.0706,  0.8817,  0.1850,  ..., -0.0875,  0.0828,  0.6999],
#         [ 0.9073,  0.2710,  0.9453,  ..., -0.1008, -0.8766, -1.6422],
#         [ 0.1462,  0.1366,  0.5575,  ..., -0.7116, -0.1804, -0.7887],
#         ...,
#         [-0.7479, -0.2158,  0.9840,  ...,  0.0507,  0.1247,  0.4779],
#         [-0.0898, -0.0664,  0.1271,  ..., -0.3905,  0.2266,  0.6929],
#         [-0.1669, -0.0281, -0.6965,  ...,  0.7204,  1.1612, -0.3478]],
#        device='cuda:0', requires_grad=True)
# Layer 2
# torch.Size([16, 48])
# Parameter containing:
# tensor([[-6.4465e-02, -1.0213e+00,  9.9517e-01,  4.1901e-01, -3.5492e-01,
#          -1.1138e+00, -4.2743e-01,  5.3006e-01, -1.8814e+00,  3.3486e-01,
#           4.3346e-01,  5.5507e-01,  2.1036e-01, -1.5811e-01, -1.6214e-01,
#           4.8606e-01, -8.9539e-01, -1.2283e+00, -3.0397e-01, -1.6822e+00,
#         [-0.7949, -1.7874, -1.3410, -0.7685, -0.2925, -1.0398, -0.5554, -1.0751,
#          -0.5508, -0.3448, -0.2064, -1.1027, -0.4977, -0.2829, -0.6141, -1.0595],
#         [-0.6451, -4.0306, -1.5000, -0.8885, -0.4223, -1.5157, -0.6590, -7.1063,
#          -0.6436, -0.6710, -0.1781, -0.6705, -0.7287, -0.2317, -0.4644, -1.0977]],
#        device='cuda:0', requires_grad=True)

# %%
# Define model with spiking layer based on trained weights

class SpikingNeuralNetwork(nn.Module):
    def __init__(self):
        """ Builds custom model with added spiking layer """
        super().__init__()
        self.ff = nn.Sequential(
            nn.Linear(64, 48, bias=False),
            nn.ReLU()
        )
        self.rnn = SNN()
        self.rnn.add_layer(w_2, rec=True, w_r=w_3)
        self.out = nn.Sequential(
            nn.Linear(16, 6, bias=False),
            nn.LogSoftmax(dim=1),
        )
        with torch.no_grad():
            self.ff[0].weight = nn.Parameter(param_list[0].cpu())
            self.out[0].weight = nn.Parameter(param_list[3].cpu())
    
    def forward(self, q, t_b, t_d, single):
        """ Implements feed-forward then recurrent layer """
        if single:
           global spike_words 
        else:
            spike_words = None
        ff_q = []
        for word in q:
            ff_q.append(self.ff(word))
        ff_q = torch.stack(ff_q)
        for word in ff_q:
            if not torch.all(word.eq(0)):
                word = word / word.sum().item() # normalize
                spike_word = poisson_train(word.cpu().detach().numpy()[0], t_b)
                rnn_out = self.rnn.infer(spike_word, t_b, t_d)
                if single:
                    spike_words.append(spike_word)
            else:
                break
        if not single:
            self.rnn.clear_lays()
        rnn_out = torch.FloatTensor(np.array([rnn_out])).to(device)
        output = self.out(rnn_out)
        return output
    
    def thresh_bal(self, q, t_b, t_d):
        """ Performs threshold balancing on recurrent layer """
        ff_q = []
        for word in q:
            ff_q.append(self.ff(word))
        ff_q = torch.stack(ff_q)
        for word in ff_q:
            if not torch.all(word.eq(0)):
                word = word / word.sum().item() # normalize
                spike_word = poisson_train(word.cpu().detach().numpy()[0], t_b)
                rnn_out = self.rnn.thresh_bal(spike_word, t_b, t_d)
            else:
                break
        self.rnn.clear_lays()

# create model
snn_model = SpikingNeuralNetwork()
snn_model.to(device)
print(snn_model)
# Out:
# SpikingNeuralNetwork(
#   (ff): Sequential(
#     (0): Linear(in_features=64, out_features=48, bias=False)
#     (1): ReLU()
#   )
#   (out): Sequential(
#     (0): Linear(in_features=16, out_features=6, bias=False)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %%
# check parameters
snn_param_list = [*snn_model.parameters()]
i=0
for lay in snn_param_list:
    i += 1
    print("Layer {0}".format(i))
    print(lay.shape)
    print(lay)
    
print(snn_model.rnn)
print("Input weight shape: {0}".format(snn_model.rnn.layers[0].w.shape))
print(snn_model.rnn.layers[0].w)
print("Recurrent weight shape: {0}".format(snn_model.rnn.layers[0].w_r.shape))
print(snn_model.rnn.layers[0].w_r)
# Out:
# Layer 1
# torch.Size([48, 64])
# Parameter containing:
# tensor([[-0.0706,  0.8817,  0.1850,  ..., -0.0875,  0.0828,  0.6999],
#    0.255677   -1.8099028  -0.8669323  -0.08286183]
#  [ 0.4124211  -0.88935924  0.9751499  -0.38582516  0.04415641  0.4394608
#    0.         -1.8167237  -0.9739797   0.06179398  0.0158397  -0.12752621
#    0.2084817  -0.20316587  0.53523004 -0.54835594]
#  [-0.8671287  -0.648699   -0.37429705 -0.8368174   0.0168722  -1.0345458
#   -1.3141086   0.         -0.35523447 -1.1978453  -1.183278    0.32584304
#   -1.4129158  -0.42406914 -0.41610533 -0.3807723 ]
#  [-0.39799908  0.23317502  0.34812114  0.17979087  0.01444228 -0.50800025
#    0.10525823  0.26522908  0.          0.16473551 -0.9175414  -0.03162239
#   -0.5122559   0.13514559  0.27146947  0.38956812]
#  [ 0.2547437  -0.48673838  0.07974375  0.6269754   0.57698935 -0.6670252
#   -0.04399965  0.57208955 -0.2434774   0.         -0.19307734 -0.9643381
#    0.41627666 -0.07922224 -0.0532974  -0.01362733]
#  [-1.7267764  -1.9547476  -0.99146557  0.68377674 -0.30849183  0.10840081
#    0.61852306  0.94561213 -1.950645   -0.06288127  0.          0.4316892
#    0.31079304  0.20608391 -0.1483618  -0.5615492 ]
#  [ 0.12863994 -2.0587938  -1.1127684   0.3245215  -0.05524796 -0.4901862
#    0.03948091  1.5921252  -0.21728392 -0.7231282   0.27548292  0.
#   -1.783994    0.05627757  0.5210154  -0.49384406]
#  [ 0.5669073   0.23896694  0.10893075  0.01752402  0.12386163  0.35711914
#    0.2728993   0.17340772  0.20585221  0.05857523  0.49494576 -0.00816171
#    0.         -0.7122442  -2.1093862  -0.13045235]
#  [ 0.16569506  0.06959758 -0.06330964  0.21420911  0.04163054 -2.55288
#   -0.33970466  0.44305074  0.5102756   0.20598985  0.02433377  0.74770737
#   -0.26434684  0.          0.41012087  0.44012925]
#  [-0.11194263 -0.40288883 -0.10651707  0.04137387 -0.09682597 -0.60438275
#   -0.44501248  1.381437    0.15467317 -0.14827709 -0.75070715  1.0168387
#   -2.4266207   0.38934085  0.          0.43016344]
#  [ 0.39535964  0.93542576 -0.21152565 -1.4116546   0.06266016 -2.2791798
#   -0.90679014  0.3017106  -0.07956903 -0.05400515 -3.1429043  -0.709851
#   -0.60608906  0.56361103  0.2451548   0.        ]]

# %%
# define test routine
def test_spikes(dataloader, model, loss_fn, t_b, t_d, single=False, verbose=False):
    size = len(dataloader.dataset)
    if single:
        num_batches = 1
    else:
        num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    inf_list, act_list = [], []
    i = 0
    with torch.no_grad():
        #for X, y in tqdm(dataloader):
        for X, y in dataloader:
            X, y = torch.stack(X).to(device), y.to(device)
            pred = snn_model.forward(X, t_b, t_d, single)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            inf_list.append(pred.argmax(1).item())
            act_list.append(y.item())
            if verbose:
                print("Actual: {0} -- Inferred: {1}".format(y.item(), pred.argmax(1).item()))
            if single:
                break
    test_loss /= num_batches
    correct /= num_batches
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return inf_list, act_list

# %% [markdown]
# ## Perform Threshold Balancing

# %%
t_b = 50 # (post-rate-conversion) input spike size
t_d = 50 # communication delay between neurons
num = 0 # number of sentences to use for threshold balancing -- if 0, uses all
i = 0
for X, y in tqdm(test_dataloader):
    X = torch.stack(X).to(device)
    snn_model.thresh_bal(X, t_b, t_d)
    i+=1
    if (num != 0) and (i == num):
        break
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████|
# Actual: 3 -- Inferred: 1
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 1
# Actual: 0 -- Inferred: 1
# Actual: 1 -- Inferred: 0
# Actual: 2 -- Inferred: 0
# Actual: 3 -- Inferred: 1
# Actual: 5 -- Inferred: 1
# Actual: 1 -- Inferred: 3
# Actual: 3 -- Inferred: 1
# Actual: 3 -- Inferred: 3
# Actual: 1 -- Inferred: 2
# Actual: 3 -- Inferred: 1
# Actual: 0 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Actual: 1 -- Inferred: 1
# Test Error:
#  Accuracy: 22.6%, Avg loss: 2.390882

# %%
# visualize distrubtion of actual and inferred labels across test dataset
# NOTE: must be run AFTER running inference on test dataset

fig = plt.figure(0, figsize=(6, 3))
axs = plt.gca()
plt.title('Inferred Labels', fontweight = 'bold')
axs.hist(inf_list, 6)
axs.set_xlabel('Label', fontsize=12, fontweight='bold')
axs.set_ylabel('Count', fontsize=12, fontweight='bold')
axs.tick_params(direction='inout', length=5)
plt.show()

fig = plt.figure(1, figsize=(6, 3))
axs = plt.gca()
plt.title('Actual Labels', fontweight = 'bold')
axs.hist(act_list, 6)
axs.set_xlabel('Label', fontsize=12, fontweight='bold')
axs.set_ylabel('Count', fontsize=12, fontweight='bold')
axs.tick_params(direction='inout', length=5)
plt.show()

# %%
# visualize spikes over course of operation of one sentence

# perform inference on one sentence
t_b = 50
t_d = 50
spike_words = []
test_spikes(test_dataloader, snn_model, loss_fn, t_b, t_d, single=True, verbose=True)

# get spike times from input 
spike_words = np.concatenate(spike_words, axis=1)
num_in_dim = spike_words.shape[0]
all_spikes_in = np.empty((0, 2))
for i in range(num_in_dim):
    spike_idxs = np.nonzero(spike_words[i])[0]
    inp_num = np.ones(len(spike_idxs)) * (i+1)
    spikes_i = np.append([inp_num], [spike_idxs], axis = 0).astype(int).T
    all_spikes_in = np.append(all_spikes_in, spikes_i, axis=0)

# get times of all spikes for all neurons in recurrent layer
neur_list = snn_model.rnn.layers[0].neur_list
num_neurons = len(neur_list)
all_spikes_out = np.empty((0, 2))
for i in range(num_neurons):
    spike_idxs = np.nonzero(neur_list[i].spikes_out)[0]
    neuron_num = np.ones(len(spike_idxs)) * (i+1)
    spikes_i = np.append([neuron_num], [spike_idxs], axis = 0).astype(int).T
    all_spikes_out = np.append(all_spikes_out, spikes_i, axis=0)

# plot spikes from input
fig = plt.figure(2, figsize=(10, 2))
axs = plt.gca()
plt.title('Input Spikes from Each Element', fontweight = 'bold')
axs.scatter(all_spikes_in[:, 1] / t_b, all_spikes_in[:, 0], c='red', s = 3)
axs.set_xlabel('Word [pos. in sentence]', fontsize=12, fontweight='bold')
axs.set_ylabel('Input Element [#]', fontsize=12, fontweight='bold')
axs.tick_params(direction='inout', length=5)
plt.show()

# plot spikes over the course of processing sentence
fig = plt.figure(3, figsize=(10, 2))
axs = plt.gca()
plt.title('Output Spikes from Each Neuron', fontweight = 'bold')
axs.scatter(all_spikes_out[:, 1] / t_b, all_spikes_out[:, 0], c='red', s = 3)
axs.set_xlabel('Word [pos. in sentence]', fontsize=12, fontweight='bold')
axs.set_ylabel('Neuron [#]', fontsize=12, fontweight='bold')
axs.tick_params(direction='inout', length=5)
plt.show()

# clear spiking neuron data so we can test another question
snn_model.rnn.clear_lays()
# Out:
# Actual: 1 -- Inferred: 1
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.000015
